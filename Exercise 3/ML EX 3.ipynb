# %%
import pandas as pd
from sklearn import preprocessing

# %%
churn_df = pd.read_csv('telecom_customer_churn.csv')
churn_df.head()
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1  0003-MKNFE    Male   46      No                     0      Glendale
# 2  0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3  0011-IGKFF    Male   78     Yes                     0      Martinez
# 4  0013-EXCHZ  Female   75     Yes                     0     Camarillo
#
#    Zip Code   Latitude   Longitude  Number of Referrals  ...   Payment Method  \
# 0     93225  34.827662 -118.999073                    2  ...      Credit Card
# 1     91206  34.162515 -118.203869                    0  ...      Credit Card
# 2     92627  33.645672 -117.922613                    0  ...  Bank Withdrawal
# 3     94553  38.014457 -122.115432                    1  ...  Bank Withdrawal
# 4     93010  34.227846 -119.079903                    3  ...      Credit Card
#
# ...

# %%
churn_df = churn_df.drop(['Customer ID', 'City', 'Zip Code', 'Latitude', 'Longitude', 'Churn Category', 'Churn Reason'], axis = 1)
churn_df.head()
# Out:
#    Gender  Age Married  Number of Dependents  Number of Referrals  \
# 0  Female   37     Yes                     0                    2
# 1    Male   46      No                     0                    0
# 2    Male   50      No                     0                    0
# 3    Male   78     Yes                     0                    1
# 4  Female   75     Yes                     0                    3
#
#    Tenure in Months    Offer Phone Service  Avg Monthly Long Distance Charges  \
# 0                 9     None           Yes                              42.39
# 1                 9     None           Yes                              10.69
# 2                 4  Offer E           Yes                              33.65
# 3                13  Offer D           Yes                              27.82
# 4                 3     None           Yes                               7.38
#
#   Multiple Lines  ...        Contract Paperless Billing   Payment Method  \
# ...

# %%
churn_df.shape
# Out:
# (6589, 31)

# %%
churn_df['Avg Monthly Long Distance Charges'] = churn_df['Avg Monthly Long Distance Charges'].fillna(0)
churn_df['Avg Monthly GB Download'] = churn_df['Avg Monthly GB Download'].fillna(0)
churn_df['Multiple Lines'] = churn_df['Multiple Lines'].fillna('No')

# %%
cols = ['Internet Type', 'Online Security', 'Online Backup', 'Device Protection Plan', 'Premium Tech Support', 'Streaming TV', 'Streaming Movies', 'Streaming Music', 'Unlimited Data']
churn_df[cols] = churn_df[cols].fillna('No')
churn_df.head()
# Out:
#    Gender  Age Married  Number of Dependents  Number of Referrals  \
# 0  Female   37     Yes                     0                    2
# 1    Male   46      No                     0                    0
# 2    Male   50      No                     0                    0
# 3    Male   78     Yes                     0                    1
# 4  Female   75     Yes                     0                    3
#
#    Tenure in Months    Offer Phone Service  Avg Monthly Long Distance Charges  \
# 0                 9     None           Yes                              42.39
# 1                 9     None           Yes                              10.69
# 2                 4  Offer E           Yes                              33.65
# 3                13  Offer D           Yes                              27.82
# 4                 3     None           Yes                               7.38
#
#   Multiple Lines  ...        Contract Paperless Billing   Payment Method  \
# ...

# %%
obj = list(churn_df.select_dtypes(include=['object']).columns)
churn_df[obj]
label_encoder = preprocessing.LabelEncoder() 
for col in obj:
    churn_df[col] = label_encoder.fit_transform(churn_df[col])
churn_df.head()
# Out:
#    Gender  Age  Married  Number of Dependents  Number of Referrals  \
# 0       0   37        1                     0                    2
# 1       1   46        0                     0                    0
# 2       1   50        0                     0                    0
# 3       1   78        1                     0                    1
# 4       0   75        1                     0                    3
#
#    Tenure in Months  Offer  Phone Service  Avg Monthly Long Distance Charges  \
# 0                 9      0              1                              42.39
# 1                 9      0              1                              10.69
# 2                 4      5              1                              33.65
# 3                13      4              1                              27.82
# 4                 3      0              1                               7.38
#
#    Multiple Lines  ...  Contract  Paperless Billing  Payment Method  \
# ...

# %%
X = churn_df.iloc[:,:-1].values
Y = churn_df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(random_state=42, max_iter=5000)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('Y_pred', y_pred)
print('Y_test', y_test)
# Out:
# Y_pred [0 1 1 ... 0 1 0]
# Y_test [0 1 1 ... 1 1 0]

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

accuracy=accuracy_score(y_test,y_pred)*100
print("Accuracy of the model is {:.2f}".format(accuracy))
# Out:
# Accuracy of the model is 84.47

# %%
from sklearn.metrics import f1_score
f1=f1_score(y_test,y_pred,average="macro")*100
print("F1 score of the model is {:.2f}".format(f1))
# Out:
# F1 score of the model is 80.95

# %%
from sklearn.metrics import recall_score
recall=recall_score(y_test,y_pred,average="macro")*100
print("Recall score of the model is {:.2f}".format(recall))
# Out:
# Recall score of the model is 80.74

# %%
from sklearn.metrics import precision_score
precision=precision_score(y_test,y_pred,average="macro")*100
print("Precision score of the model is {:.2f}".format(precision))
# Out:
# Precision score of the model is 81.17
